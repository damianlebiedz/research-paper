# %%
# COLAB CONFIGURATION
TOKEN=""
USERNAME=""

# %%
# !git clone https://$TOKEN@github.com/$USERNAME/research-paper.git

# %%
# %cd /content/$REPO

# %%
# !git checkout <BRANCH>

# %%
# !git pull

# %%
import sys
sys.path.append(f'/content/research-paper/modules')

# %%
# !pip install -r requirements.txt
