# %%
# Install the necessary packages
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas~=2.3.3 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: python-binance~=1.0.30 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (1.0.30)
# Requirement already satisfied: python-dotenv~=1.1.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: tqdm~=4.67.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: requests~=2.32.5 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: numpy~=2.3.4 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (2.3.4)
# Requirement already satisfied: seaborn~=0.13.2 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: matplotlib~=3.10.7 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (3.10.7)
# Requirement already satisfied: statsmodels~=0.14.5 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from -r ../requirements.txt (line 9)) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from pandas~=2.3.3->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from pandas~=2.3.3->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from pandas~=2.3.3->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: six in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from python-binance~=1.0.30->-r ../requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: dateparser in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from python-binance~=1.0.30->-r ../requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: aiohttp in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from python-binance~=1.0.30->-r ../requirements.txt (line 2)) (3.13.1)
# Requirement already satisfied: websockets in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from python-binance~=1.0.30->-r ../requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: pycryptodome in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from python-binance~=1.0.30->-r ../requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: colorama in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from tqdm~=4.67.1->-r ../requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from requests~=2.32.5->-r ../requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from requests~=2.32.5->-r ../requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from requests~=2.32.5->-r ../requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from requests~=2.32.5->-r ../requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from matplotlib~=3.10.7->-r ../requirements.txt (line 8)) (3.2.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from statsmodels~=0.14.5->-r ../requirements.txt (line 9)) (1.16.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from statsmodels~=0.14.5->-r ../requirements.txt (line 9)) (1.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from aiohttp->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from dateparser->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (2025.10.23)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\damia\pycharmprojects\research-paper\.venv\lib\site-packages (from dateparser->python-binance~=1.0.30->-r ../requirements.txt (line 2)) (5.3.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
start = "2024-01-01"
end = "2024-03-01"
interval="1h"
tickers = ["ADAUSDT","AVAXUSDT","BTCUSDT","DOGEUSDT","DOTUSDT","ETHUSDT","LINKUSDT","LTCUSDT","SOLUSDT","XRPUSDT"]

# %%
from src.data_services.data_pipeline import load_data

# 1. Load data
df = load_data(
    tickers=tickers,
    start=start,
    end=end,
    interval=interval,
)
print(df.head())
# Out:
#                      ADAUSDT  AVAXUSDT   BTCUSDT  DOGEUSDT  DOTUSDT  ETHUSDT  \
# open_time
# 2024-01-01 00:00:00   0.5979     38.94  42475.23   0.08983    8.267  2295.51
# 2024-01-01 01:00:00   0.6023     39.39  42613.56   0.09016    8.294  2303.72
# 2024-01-01 02:00:00   0.5995     39.04  42581.10   0.08980    8.253  2293.02
# 2024-01-01 03:00:00   0.5956     38.51  42330.49   0.08921    8.148  2273.81
# 2024-01-01 04:00:00   0.5953     38.21  42399.99   0.08910    8.140  2279.55
#
#                      LINKUSDT  LTCUSDT  SOLUSDT  XRPUSDT
# open_time
# 2024-01-01 00:00:00    15.122    73.06   101.96   0.6162
# 2024-01-01 01:00:00    15.167    73.34   104.12   0.6185
# 2024-01-01 02:00:00    15.065    73.16   103.69   0.6154
# 2024-01-01 03:00:00    14.931    72.67   103.07   0.6130
# 2024-01-01 04:00:00    14.920    72.53   102.62   0.6116

# %%
# 1. Calculate Pearson's correlation matrix

from src.pair_selection.corr_coint_tests import pearson_correlation

corr_prices_df = pearson_correlation(df).sort_values('corr', ascending=False).reset_index(drop=True)
corr_prices_df = corr_prices_df.rename(columns={'corr': 'corr_prices'})
print(corr_prices_df.head())
# Out:
#                pair  corr_prices
# 0  AVAXUSDT-SOLUSDT     0.926325
# 1   ADAUSDT-DOTUSDT     0.917982
# 2   BTCUSDT-ETHUSDT     0.909241
# 3  ADAUSDT-AVAXUSDT     0.844651
# 4   ADAUSDT-BTCUSDT     0.842703

# %%
# 2. Calculate returns correlation

returns = (df / df.shift(1) - 1).dropna()
corr_returns_df = pearson_correlation(returns).sort_values('corr', ascending=False).reset_index(drop=True)
corr_returns_df = corr_returns_df.rename(columns={'corr': 'corr_returns'})
print(corr_returns_df.head())
# Out:
#                pair  corr_returns
# 0   ADAUSDT-DOTUSDT      0.824841
# 1  AVAXUSDT-SOLUSDT      0.820279
# 2  AVAXUSDT-DOTUSDT      0.784385
# 3  ADAUSDT-AVAXUSDT      0.762790
# 4   ADAUSDT-ETHUSDT      0.752311

# %%
# 3. Calculate log-returns correlation
import numpy as np

log_returns = np.log(df / df.shift(1)).dropna()
corr_log_returns_df = pearson_correlation(log_returns).sort_values('corr', ascending=False).reset_index(drop=True)
corr_log_returns_df = corr_log_returns_df.rename(columns={'corr': 'corr_log_returns'})
print(corr_log_returns_df.head())
# Out:
#                pair  corr_log_returns
# 0   ADAUSDT-DOTUSDT          0.826138
# 1  AVAXUSDT-SOLUSDT          0.821408
# 2  AVAXUSDT-DOTUSDT          0.785760
# 3  ADAUSDT-AVAXUSDT          0.764557
# 4   ADAUSDT-ETHUSDT          0.753668

# %%
# 4. Perform Engle-Granger cointegration test

from src.pair_selection.corr_coint_tests import engle_granger_cointegration

eg_df = engle_granger_cointegration(df, tickers).sort_values('p_value', ascending=True).reset_index(drop=True)
print(eg_df.head())
# Out:
#                pair     score   p_value
# 0   ADAUSDT-BTCUSDT -3.790522  0.013955
# 1   BTCUSDT-SOLUSDT -3.258414  0.060690
# 2   ADAUSDT-ETHUSDT -3.231670  0.064789
# 3   DOTUSDT-ETHUSDT -3.041725  0.100618
# 4  DOGEUSDT-ETHUSDT -2.992856  0.111914

# %%
# 5. Perform Johansen cointegration test

from src.pair_selection.corr_coint_tests import johansen_cointegration

johansen_df = johansen_cointegration(df, tickers).sort_values('p_est', ascending=True).reset_index(drop=True)
print(johansen_df.head())
# Out:
#                pair  trace_stat  crit_95     p_est
# 0   ADAUSDT-BTCUSDT   17.156938  15.4943  0.010000
# 1   DOTUSDT-XRPUSDT   14.918801  15.4943  0.037143
# 2  DOGEUSDT-LTCUSDT   14.389188  15.4943  0.071324
# 3   ETHUSDT-LTCUSDT   14.262345  15.4943  0.079510
# 4   BTCUSDT-LTCUSDT   14.218298  15.4943  0.082353

# %%
# 6. Merge dataframes

from src.data_services.data_pipeline import merge_by_pair

merged_df = merge_by_pair(
    dfs=[corr_prices_df, corr_returns_df, corr_log_returns_df, eg_df, johansen_df],
    keep_cols=[
        ['corr_prices'],
        ['corr_returns'],
        ['corr_log_returns'],
        ['p_value'],
        ['p_est']
    ]
).sort_values('p_value', ascending=True).reset_index(drop=True)
print(merged_df.head())
# Out:
#                pair  corr_prices  corr_returns  corr_log_returns   p_value  \
# 0   ADAUSDT-BTCUSDT     0.842703      0.710358          0.711226  0.013955
# 1   BTCUSDT-SOLUSDT     0.834386      0.672675          0.674951  0.060690
# 2   ADAUSDT-ETHUSDT     0.804337      0.752311          0.753668  0.064789
# 3   DOTUSDT-ETHUSDT     0.648552      0.738975          0.740521  0.100618
# 4  DOGEUSDT-ETHUSDT     0.683948      0.565895          0.577014  0.111914
#
#       p_est
# 0  0.010000
# 1  0.109625
# 2  0.243973
# 3  0.093213
# 4  0.259850

# %%
merged_df['corr_returns x (1 - p_value)'] = merged_df['corr_returns'] * (1 - merged_df['p_value'])
print(merged_df.sort_values('corr_returns x (1 - p_value)', ascending=False).head())
# Out:
#                pair  corr_prices  corr_returns  corr_log_returns   p_value  \
# 2   ADAUSDT-ETHUSDT     0.804337      0.752311          0.753668  0.064789
# 0   ADAUSDT-BTCUSDT     0.842703      0.710358          0.711226  0.013955
# 3   DOTUSDT-ETHUSDT     0.648552      0.738975          0.740521  0.100618
# 1   BTCUSDT-SOLUSDT     0.834386      0.672675          0.674951  0.060690
# 5  AVAXUSDT-ETHUSDT     0.580218      0.706856          0.709313  0.116415
#
#       p_est  corr_returns x (1 - p_value)
# 2  0.243973                      0.703569
# 0  0.010000                      0.700445
# 3  0.093213                      0.664622
# 1  0.109625                      0.631850
# 5  0.191566                      0.624567
