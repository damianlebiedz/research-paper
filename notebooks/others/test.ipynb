# %%
from modules.data_services.data_pipeline import load_pair, calculate_rolling_zscore
from modules.visualization.plots import plot_zscore

# %%
data = load_pair(x="BTCUSDT", y='ETHUSDT', start='2024-01-25', end='2024-03-01', interval='1h')
calculate_rolling_zscore(data, 7*24, 'price')
plot_zscore(data)
# Out:
# C:\Users\Damia\PyCharmProjects\research-paper\modules\visualization\plots.py:78: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right", fontsize="small")

# %%
data = load_pair(x="BTCUSDT", y='ETHUSDT', start='2024-01-25', end='2024-03-01', interval='1h')
calculate_rolling_zscore(data, 7*24, 'return')
plot_zscore(data)
# Out:
# C:\Users\Damia\PyCharmProjects\research-paper\modules\visualization\plots.py:78: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right", fontsize="small")

# %%
data = load_pair(x="BTCUSDT", y='ETHUSDT', start='2024-01-25', end='2024-03-01', interval='1h')
calculate_rolling_zscore(data, 7*24, 'log_return')
plot_zscore(data)
# Out:
# C:\Users\Damia\PyCharmProjects\research-paper\modules\visualization\plots.py:78: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right", fontsize="small")

# %%
from modules.data_services.data_pipeline import calculate_rolling_zscore_with_rolling_beta

data = load_pair(x="BTCUSDT", y='ETHUSDT', start='2024-01-25', end='2024-03-01', interval='1h')
calculate_rolling_zscore_with_rolling_beta(data, 7*24)
plot_zscore(data)
# Out:
# C:\Users\Damia\PyCharmProjects\research-paper\modules\visualization\plots.py:78: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc="upper right", fontsize="small")
